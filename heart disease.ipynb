# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\ccana\Downloads\2020\heart_2020_cleaned.csv')
data.head(10)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
# 5          Yes  28.87     Yes              No     No             6.0
# 6           No  21.63      No              No     No            15.0
# 7           No  31.64     Yes              No     No             5.0
# 8           No  26.45      No              No     No             0.0
# 9           No  40.69      No              No     No             0.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0          30.0          No  Female        55-59  White
# 1           0.0          No  Female  80 or older  White
# ...

# %%
data.shape
# Out:
# (319795, 18)

# %%
data.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
data.dtypes
# Out:
# HeartDisease         object
# BMI                 float64
# Smoking              object
# AlcoholDrinking      object
# Stroke               object
# PhysicalHealth      float64
# MentalHealth        float64
# DiffWalking          object
# Sex                  object
# AgeCategory          object
# Race                 object
# Diabetic             object
# PhysicalActivity     object
# GenHealth            object
# SleepTime           float64
# Asthma               object
# KidneyDisease        object
# SkinCancer           object
# dtype: object

# %%
data['MentalHealth']
# Out:
# 0         30.0
# 1          0.0
# 2         30.0
# 3          0.0
# 4          0.0
#           ...
# 319790     0.0
# 319791     0.0
# 319792     0.0
# 319793     0.0
# 319794     0.0
# Name: MentalHealth, Length: 319795, dtype: float64

# %%
data['MentalHealth'].unique()
# Out:
# array([30.,  0.,  2.,  5., 15.,  8.,  4.,  3., 10., 14., 20.,  1.,  7.,
#        24.,  9., 28., 16., 12.,  6., 25., 17., 18., 21., 29., 22., 13.,
#        23., 27., 26., 11., 19.])

# %%
data['Diabetic']
# Out:
# 0         Yes
# 1          No
# 2         Yes
# 3          No
# 4          No
#          ...
# 319790    Yes
# 319791     No
# 319792     No
# 319793     No
# 319794     No
# Name: Diabetic, Length: 319795, dtype: object

# %%
data['Diabetic'].unique()
# Out:
# array(['Yes', 'No', 'No, borderline diabetes', 'Yes (during pregnancy)'],
#       dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data['HeartDisease']
# Out:
# 0          No
# 1          No
# 2          No
# 3          No
# 4          No
#          ...
# 319790    Yes
# 319791     No
# 319792     No
# 319793     No
# 319794     No
# Name: HeartDisease, Length: 319795, dtype: object

# %%
ch = LabelEncoder()
y_encoded=ch.fit(data['HeartDisease'])
data['HeartDisease'] = ch.transform(data['HeartDisease'])

# %%
data
# Out:
#         HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0                  0  16.60     Yes              No     No             3.0
# 1                  0  20.34      No              No    Yes             0.0
# 2                  0  26.58     Yes              No     No            20.0
# 3                  0  24.21      No              No     No             0.0
# 4                  0  23.71      No              No     No            28.0
# ...              ...    ...     ...             ...    ...             ...
# 319790             1  27.41     Yes              No     No             7.0
# 319791             0  29.84     Yes              No     No             0.0
# 319792             0  24.24      No              No     No             0.0
# 319793             0  32.81      No              No     No             0.0
# 319794             0  46.56      No              No     No             0.0
#
# ...

# %%
data['HeartDisease']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 319790    1
# 319791    0
# 319792    0
# 319793    0
# 319794    0
# Name: HeartDisease, Length: 319795, dtype: int32

# %%
get_ = [col for col in data.columns if data[col].dtypes == 'float']
get_
# Out:
# ['BMI', 'PhysicalHealth', 'MentalHealth', 'SleepTime']

# %%
get_ = [col for col in data.columns if data[col].dtypes == 'int']
get_
# Out:
# ['HeartDisease']

# %%
get_ = [col for col in data.columns if data[col].dtypes == 'object']
get_
# Out:
# ['Smoking',
#  'AlcoholDrinking',
#  'Stroke',
#  'DiffWalking',
#  'Sex',
#  'AgeCategory',
#  'Race',
#  'Diabetic',
#  'PhysicalActivity',
#  'GenHealth',
#  'Asthma',
#  'KidneyDisease',
#  'SkinCancer']

# %%
plt.figure(figsize = (16,8))
for i in get_:
    sns.catplot(y = "HeartDisease", x = i, hue = "Sex",data = data, kind = "bar")

# %%
for i in get_:
    sns.catplot(y = 'HeartDisease',x = i,hue = 'Sex',data = data,kind = 'point')
